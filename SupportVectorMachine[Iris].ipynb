# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
Iris=pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
Iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
Iris['target']=iris.target

# %%
Iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
Iris[Iris.target==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1
# 54       1

# %%
Iris[Iris.target==2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target
# 100       2
# 101       2
# 102       2
# 103       2
# 104       2

# %%
Iris['flower_name']=Iris.target.apply(lambda x:iris.target_names[x])
Iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target flower_name
# ...

# %%
Iris[45:55]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 45                4.8               3.0                1.4               0.3
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target flower_name
# 45       0      setosa
# 46       0      setosa
# 47       0      setosa
# 48       0      setosa
# ...

# %%
Iris0=Iris[:50]
Iris1=Iris[50:100]
Iris2=Iris[100:]

# %%
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.scatter(Iris0['sepal length (cm)'],Iris0['sepal width (cm)'],color='skyblue',marker='+')
plt.scatter(Iris1['sepal length (cm)'],Iris1['sepal width (cm)'],color='pink',marker='*')
plt.scatter(Iris2['sepal length (cm)'],Iris2['sepal width (cm)'],color='gray',marker='o')

# %%
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.scatter(Iris0['petal length (cm)'],Iris0['petal width (cm)'],color='skyblue',marker='+')
plt.scatter(Iris1['petal length (cm)'],Iris1['petal width (cm)'],color='pink',marker='*')
plt.scatter(Iris2['petal length (cm)'],Iris2['petal width (cm)'],color='gray',marker='o')

# %%
from sklearn.model_selection import train_test_split

# %%
x=Iris.drop(['target','flower_name'],axis='columns')

# %%
y=Iris.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 120

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
model_c=SVC(C=10)
model_c.fit(x_train,y_train)
model_c.score(x_test,y_test)
# Out:
# 1.0

# %%
model_c=SVC(C=1)
model_c.fit(x_train,y_train)
model_c.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
model_linear_kernel=SVC(kernel='linear')
model_linear_kernel.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
model_g=SVC(gamma=10)
model_g.fit(x_train,y_train)
model_g.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
model_linear_kernel=SVC(kernel='linear')
model_linear_kernel.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
model_linear_kernel.score(x_test,y_test)
# Out:
# 1.0
