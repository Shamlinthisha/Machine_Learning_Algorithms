# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
#from sklearn.cluster import AgglomerativeClustering

# %%
wine=datasets.load_wine()
data=wine.data
labels=wine.target

df=pd.DataFrame(data,columns=wine.feature_names)
df.head()

selected_features=['alcohol','malic_acid']
scaler=StandardScaler()
scales_data=scaler.fit_transform(df[selected_features])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
wine=pd.read_csv('/content/drive/MyDrive/Data Analytics/wine.csv')

# %%
wine
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
wine=wine.drop(['Wine','Ash','Acl','Mg','Phenols','Flavanoids','Nonflavanoid.phenols','Proanth','Color.int','Proline','OD','Hue'],axis=1)

# %%
data=np.array

# %%
wine
# Out:
#      Alcohol  Malic.acid
# 0      14.23        1.71
# 1      13.20        1.78
# 2      13.16        2.36
# 3      14.37        1.95
# 4      13.24        2.59
# ..       ...         ...
# 173    13.71        5.65
# 174    13.40        3.91
# 175    13.27        4.28
# 176    13.17        2.59
# 177    14.13        4.10
#
# [178 rows x 2 columns]

# %%
linked=linkage(wine,method='single')

# %%
dendrogram(linked,orientation='top',distance_sort='descending',show_leaf_counts=False,truncate_mode='lastp',p=30)
#plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
